# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# Creating a DataFrame

# %%
classes = pd.Series(['Maths', 'Chemistry', 'Physics', 'History', 'Geography'])
grades = pd.Series([90, 54, 77, 22, 25])
dataframe = pd.DataFrame({'Subjects':classes, 'Grades': grades})
dataframe.head()
# Out:
#     Subjects  Grades
# 0      Maths      90
# 1  Chemistry      54
# 2    Physics      77
# 3    History      22
# 4  Geography      25

# %% [markdown]
# Load the dataframe

# %%
dataframe = pd.read_csv('data/black_friday_sale.csv', 
                        index_col=0 # indicates first columns as the index
                        )

# %%
# Just show us the first rows in the dataframe
dataframe.head(n=10) # n: represent the number of columns
# Out:
#         Product_ID Gender    Age  ...  Product_Category_1 Product_Category_2 Product_Category_3
# User_ID                           ...
# 1000004  P00128942      M  46-50  ...                   1               11.0                NaN
# 1000009  P00113442      M  26-35  ...                   3                5.0                NaN
# 1000010  P00288442      F  36-45  ...                   5               14.0                NaN
# 1000010  P00145342      F  36-45  ...                   4                9.0                NaN
# 1000011  P00053842      F  26-35  ...                   4                5.0               12.0
# 1000013  P00350442      M  46-50  ...                   2                3.0               15.0
# 1000013  P00155442      M  46-50  ...                   1               11.0               15.0
# 1000013   P0094542      M  46-50  ...                   2                4.0                9.0
# 1000015  P00161842      M  26-35  ...                  10               13.0               16.0
# 1000022  P00067942      M  18-25  ...                   5               14.0                NaN
#
# [10 rows x 10 columns]

# %% [markdown]
# The method `describe()` just works for numerical values, the rest are ignored.

# %%
dataframe.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3
# count  233599.000000   233599.000000       233599.000000       161255.000000        71037.000000
# mean        8.085407        0.410070            5.276542            9.849586           12.669454
# std         6.521146        0.491847            3.736380            5.094943            4.125944
# min         0.000000        0.000000            1.000000            2.000000            3.000000
# 25%         2.000000        0.000000            1.000000            5.000000            9.000000
# 50%         7.000000        0.000000            5.000000            9.000000           14.000000
# 75%        14.000000        1.000000            8.000000           15.000000           16.000000
# max        20.000000        1.000000           18.000000           18.000000           18.000000

# %% [markdown]
# Now we will clean the data. We could have:
#
# - Empty cells
# - Data in wrong format
# - Wrong data
# - Duplicates

# %%
# Remove empty cells
new_dataframe = dataframe.dropna()
new_dataframe.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3
# count  71037.000000    71037.000000        71037.000000        71037.000000        71037.000000
# mean       8.219801        0.402002            2.725185            6.882287           12.669454
# std        6.482756        0.490306            2.564070            4.510544            4.125944
# min        0.000000        0.000000            1.000000            2.000000            3.000000
# 25%        3.000000        0.000000            1.000000            2.000000            9.000000
# 50%        7.000000        0.000000            1.000000            6.000000           14.000000
# 75%       14.000000        1.000000            4.000000           10.000000           16.000000
# max       20.000000        1.000000           15.000000           16.000000           18.000000

# %% [markdown]
# Values from `Occupation`, `Marital_Status`, `Product_Category_1` and `Product_Category_2` were removed, leaving all numerical columns with 71037 values.
#
# Nevertheless, we could fill the `nan_values` with other statistics.

# %%
# Fill nan_values with zero
new_dataframe = dataframe.fillna(value=0)
new_dataframe.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3
# count  233599.000000   233599.000000       233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542            6.799237            3.852756
# std         6.521146        0.491847            3.736380            6.217668            6.256634
# min         0.000000        0.000000            1.000000            0.000000            0.000000
# 25%         2.000000        0.000000            1.000000            0.000000            0.000000
# 50%         7.000000        0.000000            5.000000            5.000000            0.000000
# 75%        14.000000        1.000000            8.000000           14.000000            8.000000
# max        20.000000        1.000000           18.000000           18.000000           18.000000

# %%
dataframe['Product_Category_1'].replace(to_replace=np.nan, value=0, inplace=True)
dataframe['Product_Category_2'].replace(to_replace=np.nan, value=0, inplace=True)
dataframe['Product_Category_3'].replace(to_replace=np.nan, value=0, inplace=True)

dataframe['Stay_In_Current_City_Years'].replace(to_replace='4+', value='4', inplace=True)

# %%
dataframe.head()
# Out:
#         Product_ID Gender Age  ...  Product_Category_1 Product_Category_2 Product_Category_3
# User_ID                        ...
# 1000004  P00128942      M  50  ...                   1               11.0                0.0
# 1000009  P00113442      M  35  ...                   3                5.0                0.0
# 1000010  P00288442      F  45  ...                   5               14.0                0.0
# 1000010  P00145342      F  45  ...                   4                9.0                0.0
# 1000011  P00053842      F  35  ...                   4                5.0               12.0
#
# [5 rows x 10 columns]

# %%
# Obtain the unique values
dataframe.Age.unique()
# Out:
# array(['50', '35', '45', '25', '55', '60', '17'], dtype=object)

# %%
dataframe.Age.replace(to_replace=['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
                      value=['50', '35', '45', '25', '55', '60', '17'],
                      inplace=True)
dataframe.head()
# Out:
#         Product_ID Gender Age  ...  Product_Category_1 Product_Category_2 Product_Category_3
# User_ID                        ...
# 1000004  P00128942      M  50  ...                   1               11.0                0.0
# 1000009  P00113442      M  35  ...                   3                5.0                0.0
# 1000010  P00288442      F  45  ...                   5               14.0                0.0
# 1000010  P00145342      F  45  ...                   4                9.0                0.0
# 1000011  P00053842      F  35  ...                   4                5.0               12.0
#
# [5 rows x 10 columns]

# %% [markdown]
# The method `.dtypes` shows us the types of each column in the dataset.

# %%
dataframe.dtypes
# Out:
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %% [markdown]
# Now we want convert some columns in the correct `dtype`

# %%
dataframe.Age = dataframe.Age.astype('int')
dataframe.Stay_In_Current_City_Years  = dataframe.Stay_In_Current_City_Years .astype('int')
dataframe.dtypes
# Out:
# Product_ID                     object
# Gender                         object
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %% [markdown]
# Now we could use `drop_duplicate()` to eliminate duplicates values in a row or columns

# %%
dataframe.drop_duplicates(subset='Product_ID', keep='first', inplace=True, ignore_index=True)
dataframe.head()
# Out:
#   Product_ID Gender  Age  ...  Product_Category_1 Product_Category_2  Product_Category_3
# 0  P00128942      M   50  ...                   1               11.0                 0.0
# 1  P00113442      M   35  ...                   3                5.0                 0.0
# 2  P00288442      F   45  ...                   5               14.0                 0.0
# 3  P00145342      F   45  ...                   4                9.0                 0.0
# 4  P00053842      F   35  ...                   4                5.0                12.0
#
# [5 rows x 10 columns]

# %% [markdown]
# We even use pandas to obtain the correlation between variables using `.corr()`

# %%
dataframe.corr()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[38], line 1
#
# ----> 1 dataframe.corr()
#
#
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#
#   10702 cols = data.columns
#
#   10703 idx = cols.copy()
#
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#
#   10706 if method == "pearson":
#
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
#
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#
#    1887 if dtype is not None:
#
#    1888     dtype = np.dtype(dtype)
#
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#
#    1890 if result.dtype is not dtype:
#
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
#
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#
#    1654         arr.flags.writeable = False
#
#    1655 else:
#
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#
#    1657     # The underlying data was copied within _interleave, so no need
#
#    1658     # to further copy if copy=True or setting na_value
#
#    1660 if na_value is lib.no_default:
#
#
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#
#    1713     else:
#
#    1714         arr = blk.get_values(dtype)
#
# -> 1715     result[rl.indexer] = arr
#
#    1716     itemmask[rl.indexer] = 1
#
#    1718 if not itemmask.all():
#
#
#
# ValueError: could not convert string to float: 'P00128942'
